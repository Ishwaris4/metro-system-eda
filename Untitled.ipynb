# %%
from IPython.display import HTML, display

html_code= '''
<h1  style="background-color: lightpink;
color:blue; font-size: 30px;
border-radius: 20px; 
padding: 15px;
text-align:center";>

<b style="color: black;
">Python Data Exploratory Analysis</b> For Metro City Countries</h1>
'''

display(HTML(html_code))
# Out:
# <h1  style="background-color: lightpink;
# color:blue; font-size: 30px;
# border-radius: 20px;
# padding: 15px;
# text-align:center";>
#
# <b style="color: black;
# ">Python Data Exploratory Analysis</b> For Metro City Countries</h1>

# %%
from IPython.display import HTML, display

html_code= '''
<h1  style="background-color: lightpink;
color:blue; font-size: 30px;
border-radius: 20px; 
padding: 15px;
text-align:center";>

<b style="color: black;
">Import Libraries</b> Metro City Countries</h1>
'''

display(HTML(html_code))
# Out:
# <h1  style="background-color: lightpink;
# color:blue; font-size: 30px;
# border-radius: 20px;
# padding: 15px;
# text-align:center";>
#
# <b style="color: black;
# ">Import Libraries</b> Metro City Countries</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("metro_countries_cities.csv")

# %%
from IPython.display import HTML, display

html_content = '''
<h1  style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
   Understand the data
</h1>
'''
display(HTML(html_content))
# Out:
# <h1  style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
#    Understand the data
# </h1>

# %%
data.head()     # prints initial few rows
# Out:
#            city    country                      name  year  \
# 0       Algiers    Algeria             Algiers Metro  2011
# 1  Buenos Aires  Argentina  Buenos Aires Underground  1913
# 2       Yerevan    Armenia             Yerevan Metro  1981
# 3        Sydney  Australia              Sydney Metro  2019
# 4        Vienna    Austria             Vienna U-Bahn  1976
#
#    year_last_expansion  stations  length_km  annual_ridership_mill  \
# 0                 2018        19        185                  45.30
# 1                 2019        90        567                  74.00
# 2                 1996        10        134                  10.75
# 3                 2019        13         36                  12.90
# 4                 2017        98        833                 459.80
#
#           region
# 0         africa
# 1  latin_america
# 2           asia
# 3      australia
# 4         europe

# %%
data.tail()     # prints last 5 rows
# Out:
#                  city        country              name  year  \
# 193          San Juan  United States       Tren Urbano  2004
# 194  Washington, D.C.  United States  Washington Metro  1976
# 195          Tashkent     Uzbekistan    Tashkent Metro  1977
# 196           Caracas      Venezuela     Caracas Metro  1983
# 197             Hanoi        Vietnam       Hanoi Metro  2021
#
#      year_last_expansion  stations  length_km  annual_ridership_mill  \
# 193                 2005        16        172                    1.1
# 194                 2014        91        188                   68.1
# 195                 2020        39        571                   38.8
# 196                 2015        52        672                  358.0
# 197                 2021        12        131                    0.0
#
#             region
# 193  north_america
# 194  north_america
# 195           asia
# 196  latin_america
# 197           asia

# %%
data.columns     # prints the column names
# Out:
# Index(['city', 'country', 'name', 'year', 'year_last_expansion', 'stations',
#        'length_km', 'annual_ridership_mill', 'region'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   city                   198 non-null    object
#  1   country                198 non-null    object
#  2   name                   198 non-null    object
#  3   year                   198 non-null    int64
#  4   year_last_expansion    198 non-null    int64
#  5   stations               198 non-null    int64
#  6   length_km              198 non-null    int64
#  7   annual_ridership_mill  198 non-null    float64
#  8   region                 198 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 14.1+ KB

# %%
data.shape    # rows and cols
# Out:
# (198, 9)

# %%
data.ndim    # gives the dimension of data
# Out:
# 2

# %%
data.describe()     # prints the statistics on our data
# Out:
#               year  year_last_expansion    stations     length_km  \
# count   198.000000           198.000000  198.000000    198.000000
# mean   1987.858586          2014.565657   68.939394   1506.595960
# std      31.617161            13.167921   76.200753   4900.037419
# min    1890.000000          1896.000000    6.000000     12.000000
# 25%    1976.000000          2014.000000   21.000000    175.000000
# 50%    1995.500000          2019.000000   41.000000    392.000000
# 75%    2012.750000          2021.000000   90.750000   1001.250000
# max    2022.000000          2022.000000  424.000000  49039.000000
#
#        annual_ridership_mill
# count             198.000000
# mean              263.254980
# std               482.654133
# min                 0.000000
# 25%                24.025000
# 50%                92.950000
# 75%               247.925000
# max              2834.690000

# %%
from IPython.display import HTML, display

html_content = '''
<h1 style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
    Explore Regions, Countries & Cities
</h1>
'''
display(HTML(html_content))
# Out:
# <h1 style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
#     Explore Regions, Countries & Cities
# </h1>

# %%
print(len(data.region.unique()))        #  prints the len of unique region
print(data.region.unique())             # prints the names of that unique region
# Out:
# 6
# ['africa' 'latin_america' 'asia' 'australia' 'europe' 'north_america']

# %%
print(len(data.country.unique()))
print(data.country.unique())
# Out:
# 59
# ['Algeria' 'Argentina' 'Armenia' 'Australia' 'Austria' 'Azerbaijan'
#  'Belarus' 'Belgium' 'Brazil' 'Bulgaria' 'Canada' 'Chile' 'China'
#  'Colombia' 'Czech Republic' 'Denmark' 'Dominican Republic' 'Egypt'
#  'Finland' 'France' 'Georgia' 'Germany' 'Greece' 'Hungary' 'India'
#  'Indonesia' 'Iran' 'Italy' 'Japan' 'Kazakhstan' 'North Korea'
#  'South Korea' 'Malaysia' 'Mexico' 'Netherlands' 'Norway' 'Pakistan'
#  'Panama' 'Peru' 'Philippines' 'Poland' 'Portugal' 'Qatar' 'Romania'
#  'Russia' 'Singapore' 'Spain' 'Sweden' 'Switzerland' 'Taiwan' 'Thailand'
#  'Turkey' 'Ukraine' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'Uzbekistan' 'Venezuela' 'Vietnam']

# %%
print(len(data.city.unique()))
print(data.city.unique())
# Out:
# 187
# ['Algiers' 'Buenos Aires' 'Yerevan' 'Sydney' 'Vienna' 'Baku' 'Minsk'
#  'Brussels' 'Belo Horizonte' 'Brasília' 'Porto Alegre' 'Recife'
#  'Rio de Janeiro' 'Salvador' 'São Paulo' 'Sofia' 'Montreal' 'Toronto'
#  'Vancouver' 'Santiago' 'Beijing' 'Changchun' 'Changsha' 'Changzhou'
#  'Chengdu' 'Chongqing' 'Dalian' 'Dongguan' 'Foshan' 'Fuzhou' 'Guangzhou'
#  'Guiyang' 'Hangzhou' 'Harbin' 'Hefei' 'Hohhot' 'Hong Kong' 'Jinan'
#  'Kunming' 'Lanzhou' 'Luoyang' 'Nanchang' 'Nanjing' 'Nanning' 'Ningbo'
#  'Qingdao' 'Shanghai' 'Shaoxing' 'Shenyang' 'Shenzhen' 'Shijiazhuang'
#  'Suzhou' 'Taiyuan' 'Tianjin' 'Ürümqi' 'Wenzhou' 'Wuhan' 'Wuhu' 'Wuxi'
#  'Xiamen' "Xi'an" 'Xuzhou' 'Zhengzhou' 'Medellín' 'Prague' 'Copenhagen'
#  'Santo Domingo' 'Cairo' 'Helsinki' 'Lille' 'Lyon' 'Marseille' 'Paris'
#  'Rennes' 'Toulouse' 'Tbilisi' 'Berlin' 'Hamburg' 'Munich' 'Nuremberg'
#  'Athens' 'Budapest' 'Ahmedabad' 'Bengaluru' 'Chennai' 'Delhi' 'Gurgaon'
# ...

# %%
from IPython.display import HTML, display

html_content = '''
<h1 style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
    Data Imputation
</h1>
'''
display(HTML(html_content))
# Out:
# <h1 style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
#     Data Imputation
# </h1>

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# city                     0
# country                  0
# name                     0
# year                     0
# year_last_expansion      0
# stations                 0
# length_km                0
# annual_ridership_mill    0
# region                   0
# dtype: int64

# %%
from IPython.display import HTML, display

html_content = '''
<h1 style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
    Data Visualization
</h1>
'''
display(HTML(html_content))
# Out:
# <h1 style="background-color: lightpink; color: brown; border-radius: 10px; padding: 15px; text-align:center";>
#     Data Visualization
# </h1>

# %%
from IPython.display import HTML, display

html_content = '''
<div style="background-color: lightpink; border-radius: 10px; padding: 15px; text-align:left";>
    <h3 style=color: black;"> 1.Boxplots Used For: </h3>
    <span style=color: grey;"> Spread of the data, Median value, Skewness of distribution, Presence of outliers </span>
</div>
'''
display(HTML(html_content))
# Out:
# <div style="background-color: lightpink; border-radius: 10px; padding: 15px; text-align:left";>
#     <h3 style=color: black;"> 1.Boxplots Used For: </h3>
#     <span style=color: grey;"> Spread of the data, Median value, Skewness of distribution, Presence of outliers </span>
# </div>

# %%
# distribution of years and Checking values of outliers

sns.boxplot(x=data['year'])    # outliers lies before 1925
# Out:
# <Axes: xlabel='year'>

# %%
data_early_year = data.loc[(data['year'] < 1925)]
data_early_year
# Out:
#               city         country                      name  year  \
# 1     Buenos Aires       Argentina  Buenos Aires Underground  1913
# 72           Paris          France               Paris Métro  1900
# 76          Berlin         Germany             Berlin U-Bahn  1902
# 77         Hamburg         Germany            Hamburg U-Bahn  1912
# 80          Athens          Greece              Athens Metro  1904
# 81        Budapest         Hungary            Budapest Metro  1896
# 157      Barcelona           Spain           Barcelona Metro  1924
# 159         Madrid           Spain              Madrid Metro  1919
# 177        Glasgow  United Kingdom            Glasgow Subway  1896
# 178         London  United Kingdom        London Underground  1890
# 182         Boston   United States               MBTA subway  1901
# 183        Chicago   United States               Chicago "L"  1892
# 187  New York City   United States      New York City Subway  1904
# ...

# %%
from IPython.display import HTML, display

html_content = '''
<div style="background-color: lightpink; border-radius: 10px; padding: 15px; text-align:left";>
    <h3 style=color: black;"> 2.Barplots Used: </h3>
    <span style=color: grey;"> Compare averages of Categorical and Numerical values</span>
</div>
'''
display(HTML(html_content))
# Out:
# <div style="background-color: lightpink; border-radius: 10px; padding: 15px; text-align:left";>
#     <h3 style=color: black;"> 2.Barplots Used: </h3>
#     <span style=color: grey;"> Compare averages of Categorical and Numerical values</span>
# </div>

# %%
plt.figure(figsize=(5,10))             # figsize = width, height
sns.barplot(x='stations', y='city', hue='region', data=data_early_year)   # NYC shows twice that's why black line is shown
# Out:
# <Axes: xlabel='stations', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='length_km', y='city', hue='region', data=data_early_year)
# Out:
# <Axes: xlabel='length_km', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='annual_ridership_mill', y='city', hue='region', data=data_early_year)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='city'>

# %%
from IPython.display import HTML, display

html_content = '''
<div style="background-color: lightpink; border-radius: 10px; padding: 15px; text-align:left";>
    <h3 style=color: black;"> 3.Histplots Used For: </h3>
    <span style=color: grey;"> Show Distribution of Numerical Values </span>
</div>
'''
display(HTML(html_content))
# Out:
# <div style="background-color: lightpink; border-radius: 10px; padding: 15px; text-align:left";>
#     <h3 style=color: black;"> 3.Histplots Used For: </h3>
#     <span style=color: grey;"> Show Distribution of Numerical Values </span>
# </div>

# %%
sns.histplot(x='stations', hue='region', data=data_early_year)
# Out:
# <Axes: xlabel='stations', ylabel='Count'>

# %%
sns.histplot(x='length_km', hue='region', data=data_early_year)
# Out:
# <Axes: xlabel='length_km', ylabel='Count'>

# %%
sns.histplot(x='annual_ridership_mill', hue='region', data=data_early_year)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='Count'>

# %%
sns.boxplot(x=data['year_last_expansion'])    # outliers lies before 2000
plt.xlim(1990, 2020)
# Out:
# (1990.0, 2020.0)

# %%
data_expansion_early = data.loc[(data['year_last_expansion'] < 2000)]    # loc: used to select data using rows, cols names
data_expansion_early
# Out:
#               city         country                         name  year  \
# 2          Yerevan         Armenia                Yerevan Metro  1981
# 116        Sapporo           Japan     Sapporo Municipal Subway  1971
# 124      Pyongyang     North Korea              Pyongyang Metro  1973
# 160      Stockholm          Sweden              Stockholm Metro  1950
# 173         Dnipro         Ukraine                 Dnipro Metro  1995
# 177        Glasgow  United Kingdom               Glasgow Subway  1896
# 181      Baltimore   United States   Baltimore Metro SubwayLink  1983
# 184      Cleveland   United States  RTA Rapid Transit: Red Line  1955
# 189  New York City   United States                         PATH  1908
# 190   Philadelphia   United States                        SEPTA  1907
# 191   Philadelphia   United States              PATCO Speedline  1936
#
#      year_last_expansion  stations  length_km  annual_ridership_mill  \
# ...

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='stations', y='city', hue='region', data=data_expansion_early)
# Out:
# <Axes: xlabel='stations', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='length_km', y='city', hue='region', data=data_expansion_early)
# Out:
# <Axes: xlabel='length_km', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='annual_ridership_mill', y='city', hue='region', data=data_expansion_early)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='city'>

# %%
sns.histplot(x='stations', hue='region', data=data_expansion_early)
# Out:
# <Axes: xlabel='stations', ylabel='Count'>

# %%
sns.histplot(x='length_km', hue='region', data=data_expansion_early)
# Out:
# <Axes: xlabel='length_km', ylabel='Count'>

# %%
sns.histplot(x='annual_ridership_mill', hue='region', data=data_expansion_early)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='Count'>

# %%
sns.boxplot(x=data['length_km'])     # outliers from 2000
plt.xlim(0, 4000)
# Out:
# (0.0, 4000.0)

# %%
data_lengthkm_out = data.loc[(data['length_km'] > 2300)]
data_lengthkm_out
# Out:
#           city         country                       name  year  \
# 5         Baku      Azerbaijan                 Baku Metro  1967
# 23   Changzhou           China            Changzhou Metro  2019
# 24     Chengdu           China              Chengdu Metro  2010
# 25   Chongqing           China     Chongqing Rail Transit  2005
# 26      Dalian           China               Dalian Metro  2003
# 29      Fuzhou           China               Fuzhou Metro  2016
# 30   Guangzhou           China            Guangzhou Metro  1997
# 35      Hohhot           China               Hohhot Metro  2019
# 45     Qingdao           China              Qingdao Metro  2015
# 52     Taiyuan           China              Taiyuan Metro  2020
# 57        Wuhu           China          Wuhu Rail Transit  2021
# 60       Xi'an           China                Xi'an Metro  2011
# 61      Xuzhou           China               Xuzhou Metro  2019
# 85       Delhi           India                Delhi Metro  2002
# ...

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='stations', y='city', hue='region', data=data_lengthkm_out)
# Out:
# <Axes: xlabel='stations', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='length_km', y='city', hue='region', data=data_lengthkm_out)
# Out:
# <Axes: xlabel='length_km', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='annual_ridership_mill', y='city', hue='region', data=data_lengthkm_out)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='city'>

# %%
sns.histplot(x='stations', hue='region', data=data_lengthkm_out)
# Out:
# <Axes: xlabel='stations', ylabel='Count'>

# %%
sns.histplot(x='length_km', hue='region', data=data_lengthkm_out)
# Out:
# <Axes: xlabel='length_km', ylabel='Count'>

# %%
sns.histplot(x='annual_ridership_mill', hue='region', data=data_lengthkm_out)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='Count'>

# %%
sns.boxplot(x=data['stations'])    # outliers after 200
# Out:
# <Axes: xlabel='stations'>

# %%
data_stations_max = data.loc[(data['stations'] > 200)]
data_stations_max
# Out:
#               city         country                       name  year  \
# 20         Beijing           China             Beijing Subway  1971
# 24         Chengdu           China              Chengdu Metro  2010
# 25       Chongqing           China     Chongqing Rail Transit  2005
# 30       Guangzhou           China            Guangzhou Metro  1997
# 32        Hangzhou           China             Hangzhou Metro  2012
# 46        Shanghai           China             Shanghai Metro  1993
# 49        Shenzhen           China             Shenzhen Metro  2004
# 56           Wuhan           China                Wuhan Metro  2004
# 72           Paris          France                Paris Métro  1900
# 85           Delhi           India                Delhi Metro  2002
# 130          Seoul     South Korea  Seoul Metropolitan Subway  1974
# 150         Moscow          Russia               Moscow Metro  1935
# 159         Madrid           Spain               Madrid Metro  1919
# ...

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='annual_ridership_mill', y='city', hue='region', data=data_stations_max)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='stations', y='city', hue='region', data=data_stations_max)
# Out:
# <Axes: xlabel='stations', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='length_km', y='city', hue='region', data=data_stations_max)
# Out:
# <Axes: xlabel='length_km', ylabel='city'>

# %%
sns.histplot(x='length_km', hue='region', data=data_stations_max)
# Out:
# <Axes: xlabel='length_km', ylabel='Count'>

# %%
sns.histplot(x='stations', hue='region', data=data_stations_max)    # distribution of metro systems with more than 200 stations
# Out:
# <Axes: xlabel='stations', ylabel='Count'>

# %%
sns.histplot(x='annual_ridership_mill', hue='region', data=data_stations_max)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='Count'>

# %%
sns.boxplot(x=data['annual_ridership_mill'])    # outliers after  500
# Out:
# <Axes: xlabel='annual_ridership_mill'>

# %%
data_ridership_max = data.loc[(data['annual_ridership_mill'] > 500)]
data_ridership_max
# Out:
#               city        country                       name  year  \
# 14       São Paulo         Brazil            São Paulo Metro  1974
# 20         Beijing          China             Beijing Subway  1971
# 24         Chengdu          China              Chengdu Metro  2010
# 25       Chongqing          China     Chongqing Rail Transit  2005
# 30       Guangzhou          China            Guangzhou Metro  1997
# 32        Hangzhou          China             Hangzhou Metro  2012
# 36       Hong Kong          China       Mass Transit Railway  1979
# 42         Nanjing          China              Nanjing Metro  2005
# 46        Shanghai          China             Shanghai Metro  1993
# 49        Shenzhen          China             Shenzhen Metro  2004
# 56           Wuhan          China                Wuhan Metro  2004
# 60           Xi'an          China                Xi'an Metro  2011
# 67           Cairo          Egypt                Cairo Metro  1987
# ...

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='stations', y='city', hue='region', data=data_ridership_max)
# Out:
# <Axes: xlabel='stations', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='length_km', y='city', hue='region', data=data_ridership_max)
# Out:
# <Axes: xlabel='length_km', ylabel='city'>

# %%
plt.figure(figsize=(5,10))        # figsize = width, height
sns.barplot(x='annual_ridership_mill', y='city', hue='region', data=data_ridership_max)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='city'>

# %%
sns.histplot(x='stations', hue='region', data=data_ridership_max)    # distribution of metro systems with more than 500 stations
# Out:
# <Axes: xlabel='stations', ylabel='Count'>

# %%
sns.histplot(x='length_km', hue='region', data=data_ridership_max)
# Out:
# <Axes: xlabel='length_km', ylabel='Count'>

# %%
sns.histplot(x='annual_ridership_mill', hue='region', data=data_ridership_max)
# Out:
# <Axes: xlabel='annual_ridership_mill', ylabel='Count'>

# %%
from IPython.display import HTML, display

html_content = '''
<h1 style="background-color: lightpink; color:brown; border-radius: 10px; padding: 15px; text-align:center";>
    Handling the Outliers
</h1>
'''
display(HTML(html_content))
# Out:
# <h1 style="background-color: lightpink; color:brown; border-radius: 10px; padding: 15px; text-align:center";>
#     Handling the Outliers
# </h1>

# %%
numeric_data = data.select_dtypes(include='number')

Q1 = numeric_data.quantile(0.25)
Q3 = numeric_data.quantile(0.75)

IQR = Q3 - Q1

print(IQR)
# Out:
# year                      36.75
# year_last_expansion        7.00
# stations                  69.75
# length_km                826.25
# annual_ridership_mill    223.90
# dtype: float64

# %%
sns.scatterplot(x='stations', y='length_km', data=data)
plt.ylim(0, 10000)
# Out:
# (0.0, 10000.0)

# %%
sns.scatterplot(x='stations', y='annual_ridership_mill', data=data)
# Out:
# <Axes: xlabel='stations', ylabel='annual_ridership_mill'>

# %%
sns.scatterplot(x='length_km', y='annual_ridership_mill', data=data)
plt.xlim(0, 10000)
# Out:
# (0.0, 10000.0)

# %%
sns.scatterplot(x='year', y='year_last_expansion', data=data)
plt.ylim(2000, 2020)
# Out:
# (2000.0, 2020.0)

# %%
sns.scatterplot(x='year', y='stations', data=data)
# Out:
# <Axes: xlabel='year', ylabel='stations'>

# %%
sns.scatterplot(x='year', y='length_km', data=data)
# Out:
# <Axes: xlabel='year', ylabel='length_km'>

# %%
sns.pairplot(data=data)
plt.savefig("pairplot.png")

# %%
sns.pairplot(data=data, hue='region')
plt.savefig("pairplot2.png")

# %%
sns.regplot(x='annual_ridership_mill', y='stations', data=data)
plt.savefig("regplot.png")

# %%
sns.regplot(x='annual_ridership_mill', y='length_km', data=data)
plt.savefig("regplot2.png")

# %%
from IPython.display import HTML, display

html_content = '''
<h1 style="background-color: lightpink; color:brown; border-radius: 10px; padding: 15px; text-align:center";>
    Region wise analysis
</h1>
'''
display(HTML(html_content))
# Out:
# <h1 style="background-color: lightpink; color:brown; border-radius: 10px; padding: 15px; text-align:center";>
#     Region wise analysis
# </h1>

# %%
data.region.unique()
# Out:
# array(['africa', 'latin_america', 'asia', 'australia', 'europe',
#        'north_america'], dtype=object)

# %%
data_africa = data.loc[(data['region'] == 'africa')]
data_lat_america = data.loc[(data['region'] == 'latin_america')]
data_asia = data.loc[(data['region'] == 'asia')]
data_australia = data.loc[(data['region'] == 'australia')]
data_europe = data.loc[(data['region'] == 'europe')]
data_north_america = data.loc[(data['region'] == 'north_america')]

# %%
# africa region analysis
import plotly.express as px
fig = px.sunburst(data_africa, path=['region', 'city', 'name', 'stations'], values='annual_ridership_mill')
fig.show()

# %%
# latin america region analysis
import plotly.express as px
fig = px.sunburst(data_lat_america, path=['region', 'city', 'name', 'stations'], values='annual_ridership_mill')
fig.show()

# %%
# asia region analysis
import plotly.express as px
fig = px.sunburst(data_asia, path=['region', 'city', 'name', 'stations'], values='annual_ridership_mill')
fig.show()

# %%
# australia region analysis
import plotly.express as px
fig = px.sunburst(data_australia, path=['region', 'city', 'name', 'stations'], values='annual_ridership_mill')
fig.show()

# %%
# europe region analysis
import plotly.express as px
fig = px.sunburst(data_europe, path=['region', 'city', 'name', 'stations'], values='annual_ridership_mill')
fig.show()

# %%
# north america region analysis
import plotly.express as px
fig = px.sunburst(data_north_america, path=['region', 'city', 'name', 'stations'], values='annual_ridership_mill')
fig.show()

# %%
correlation = data.select_dtypes(include='number').corr()
correlation
# Out:
#                            year  year_last_expansion  stations  length_km  \
# year                   1.000000             0.371102 -0.303588   0.083004
# year_last_expansion    0.371102             1.000000  0.213859   0.112577
# stations              -0.303588             0.213859  1.000000   0.194416
# length_km              0.083004             0.112577  0.194416   1.000000
# annual_ridership_mill -0.185124             0.148290  0.768383   0.194095
#
#                        annual_ridership_mill
# year                               -0.185124
# year_last_expansion                 0.148290
# stations                            0.768383
# length_km                           0.194095
# annual_ridership_mill               1.000000

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >
